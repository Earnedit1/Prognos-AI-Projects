# %%
studName = ('Bett James', 'Namukolo Abrams', 'Vera Abutu', 'Kwame Doga', 'Lukeman Ahmad', 'Akin Torey', 'Luke Brant', 'James Kenyata', 'Ngugi Tionga', 'Okoro Eze', 'Agatha Chiluba', 'Mangu Joseph', 'Longe Jethro', 'Florence Giwa', 'Vetiva Lucent', 'Melody Braimoh', 'Victor Ihab', 'Mimi Trucker', 'Maguel Peter', 'Wellington Zuba')
studID = ('GR-0483', 'GR-0484', 'GR-0485', 'GR-0486', 'GR-0487', 'GR-0488', 'GR-0489', 'GR-0490', 'GR-0491', 'GR-0492', 'GR-0493', 'GR-0494', 'GR-0495', 'GR-0496', 'GR-0497', 'GR-0498', 'GR-0499', 'GR-0500', 'GR-0501', 'GR-0502')


{'Bett James_GR-0483': [{'Chem': [{'Quiz': 127}, {'Homework': 135}, {'Attendance': 17}, {'Exam': 46}]}, {'Bio': [{'Quiz': 184}, {'Homework': 186}, {'Attendance': 58}, {'Exam': 97}]}, {'Phy': [{'Quiz': 52}, {'Homework': 142}, {'Attendance': 29}, {'Exam': 73}]}, {'Math': [{'Quiz': 133}, {'Homework': 97}, {'Attendance': 34}, {'Exam': 45}]}, [{'avg': [{'Chem': 52.615526315789474}, {'Bio': 92.69684210526316}, {'Phy': 54.436052631578946}, {'Math': 52.25789473684211}]}, {'avgscore': 63.00157894736842}, {'gpa': 3.1500789473684208, 'grade': 'D'}, {}, {'status': 'PASS'}]], 'Namukolo Abrams_GR-0484': [{'Chem': [{'Quiz': 141}, {'Homework': 82}, {'Attendance': 95}, {'Exam': 52}]}, {'Bio': [{'Quiz': 177}, {'Homework': 170}, {'Attendance': 57}, {'Exam': 41}]}, {'Phy': [{'Quiz': 21}, {'Homework': 12}, {'Attendance': 43}, {'Exam': 31}]}, {'Math': [{'Quiz': 136}, {'Homework': 180}, {'Attendance': 48}, {'Exam': 31}]}, [{'avg': [{'Chem': 62.97184210526316}, {'Bio': 66.12342105263157}, {'Phy': 22.96815789473684}, {'Math': 55.014210526315786}]}, {'avgscore': 51.76940789473684}, {'gpa': 2.588470394736842, 'grade': 'E'}, {}, {'status': 'RETAKE'}]]}

# %%
studRecords  = dict()
def studRecCreator(name, ID, firstSubj, firstsubjCA_1, firstsubjScoreCA_1, firstsubjCA_2, firstsubjScoreCA_2, firstsubjCA_3, firstsubjScoreCA_3, firstsubjexam, firstsubjScoreExam, secondSubj, secondsubjCA_1, secondsubjScoreCA_1, secondsubjCA_2, secondsubjScoreCA_2, secondsubjCA_3, secondsubjScoreCA_3, secondsubjexam, secondsubjScoreExam, thirdSubj, thirdsubjCA_1, thirdsubjScoreCA_1, thirdsubjCA_2, thirdsubjScoreCA_2, thirdsubjCA_3, thirdsubjScoreCA_3, thirdsubjexam, thirdsubjScoreExam, forthSubj, forthsubjCA_1, forthsubjScoreCA_1, forthsubjCA_2, forthsubjScoreCA_2, forthsubjCA_3, forthsubjScoreCA_3, forthsubjexam, forthsubjScoreExam, avg, avgSub1score, avgSub2score, avgSub3score, avgSub4score, avgscore, avgscorerec, gpa, gparec, grade, graderec, status, statusrec):
    subDict1 = dict()
    subDict2 = dict()
    subDict3 = dict()
    subDict4 = dict()
    studKey = name+'_'+ID
    firstsubjCA_1Dict1 = dict()
    firstsubjCA_1Dict1[firstsubjCA_1] =  firstsubjScoreCA_1
    firstsubjCA_2Dict2 = dict()
    firstsubjCA_2Dict2[firstsubjCA_2] = firstsubjScoreCA_2
    firstsubjCA_3Dict3 = dict()
    firstsubjCA_3Dict3[firstsubjCA_3] = firstsubjScoreCA_3
    firstsubjexamDict4 = dict()
    firstsubjexamDict4[firstsubjexam] = firstsubjScoreExam
    subDict1[firstSubj] = [firstsubjCA_1Dict1, firstsubjCA_2Dict2,  firstsubjCA_3Dict3, firstsubjexamDict4]
    
    
    secondsubjCA_1Dict1 = dict()
    secondsubjCA_1Dict1[secondsubjCA_1] =  secondsubjScoreCA_1
    secondsubjCA_2Dict2 = dict()
    secondsubjCA_2Dict2[secondsubjCA_2] = secondsubjScoreCA_2
    secondsubjCA_3Dict3 = dict()
    secondsubjCA_3Dict3[secondsubjCA_3] = secondsubjScoreCA_3
    secondsubjexamDict4 = dict()
    secondsubjexamDict4[secondsubjexam] = secondsubjScoreExam
    subDict2[secondSubj] = [secondsubjCA_1Dict1, secondsubjCA_2Dict2,  secondsubjCA_3Dict3, secondsubjexamDict4]
    
    
    thirdsubjCA_1Dict1 = dict()
    thirdsubjCA_1Dict1[thirdsubjCA_1] =  thirdsubjScoreCA_1
    thirdsubjCA_2Dict2 = dict()
    thirdsubjCA_2Dict2[thirdsubjCA_2] = thirdsubjScoreCA_2
    thirdsubjCA_3Dict3 = dict()
    thirdsubjCA_3Dict3[thirdsubjCA_3] = thirdsubjScoreCA_3
    thirdsubjexamDict4 = dict()
    thirdsubjexamDict4[thirdsubjexam] = thirdsubjScoreExam
    subDict3[thirdSubj] = [thirdsubjCA_1Dict1, thirdsubjCA_2Dict2,  thirdsubjCA_3Dict3, thirdsubjexamDict4]
    
    
    forthsubjCA_1Dict1 = dict()
    forthsubjCA_1Dict1[forthsubjCA_1] =  forthsubjScoreCA_1
    forthsubjCA_2Dict2 = dict()
    forthsubjCA_2Dict2[forthsubjCA_2] = forthsubjScoreCA_2
    forthsubjCA_3Dict3 = dict()
    forthsubjCA_3Dict3[forthsubjCA_3] = forthsubjScoreCA_3
    forthsubjexamDict4 = dict()
    forthsubjexamDict4[forthsubjexam] = forthsubjScoreExam
    subDict4[forthSubj] = [forthsubjCA_1Dict1, forthsubjCA_2Dict2,  forthsubjCA_3Dict3, forthsubjexamDict4]
    
    
    #performance record
    
    subperDict1 = dict()

    avgSub1Dict1 = dict()
    avgSub1Dict1[firstSubj] =  avgSub1score

    avgSub2Dict2 = dict()
    avgSub2Dict2[secondSubj] = avgSub2score

    avgSub3Dict3 = dict()
    avgSub3Dict3[thirdSubj] = avgSub3score

    avgSub4Dict4 = dict()
    avgSub4Dict4[forthSubj] = avgSub4score


    subperDict1[avg] = [avgSub1Dict1, avgSub2Dict2,  avgSub3Dict3, avgSub4Dict4]

    avgscoreDict = dict()
    avgscoreDict[avgscore] = avgscorerec

    gpaDict = dict()
    gpaDict[gpa] = gparec

    gradeDict = dict()
    gpaDict[grade] = graderec

    statusDict = dict()
    statusDict[status] = statusrec

    studperRecords = [subperDict1, avgscoreDict, gpaDict, gradeDict, statusDict]
        
    studRecords[studKey] = [subDict1, subDict2, subDict3, subDict4, studperRecords]

# %%
#1. enables him to manually load each students scores by subject for quiz, homework, attendance, and exam using the python input() function. Use as data, the records in the Student Scores table below (Table1.0) 
#2. Automatically computes the Average Score, GPA (0 to 5.0), Grade and Status (Pass, Fail, Retake) and stores in a container for each student as per the provided rating scales below 





name = input('name: ')
ID = input('ID: ')
firstSubj = input('first subject: ')
firstsubjCA_1 = input('first assesment type: ')
firstsubjScoreCA_1 = int(input('first assesment type score: '))
firstsubjCA_2 = input('second assesment type: ')
firstsubjScoreCA_2 = int(input('second assesment type score: '))
firstsubjCA_3 = input('third assesment type:')
firstsubjScoreCA_3 = int(input('third assesment type score: '))
firstsubjexam = input('fourth assesment type: ')
firstsubjScoreExam = int(input('fourth assesment type score: '))

secondSubj = input('second subject: ')
secondsubjCA_1 = input('first assesment type: ')
secondsubjScoreCA_1 = int(input('first assesment type score: '))
secondsubjCA_2 = input('second assesment type: ')
secondsubjScoreCA_2 = int(input('second assesment type score: '))
secondsubjCA_3 = input('third assesment type:')
secondsubjScoreCA_3 = int(input('third assesment type score: '))
secondsubjexam = input('fourth assesment type: ')
secondsubjScoreExam = int(input('fourth assesment type score: '))

thirdSubj = input('third subject: ')
thirdsubjCA_1 = input('first assesment type: ')
thirdsubjScoreCA_1 = int(input('first assesment type score: '))
thirdsubjCA_2 = input('second assesment type: ')
thirdsubjScoreCA_2 = int(input('second assesment type score: '))
thirdsubjCA_3 = input('third assesment type:')
thirdsubjScoreCA_3 = int(input('third assesment type score: '))
thirdsubjexam = input('fourth assesment type: ')
thirdsubjScoreExam = int(input('fourth assesment type score: '))

forthSubj = input('forth subject: ')
forthsubjCA_1 = input('first assesment type: ')
forthsubjScoreCA_1 = int(input('first assesment type score: '))
forthsubjCA_2 = input('second assesment type: ')
forthsubjScoreCA_2 = int(input('second assesment type score: '))
forthsubjCA_3 = input('third assesment type:')
forthsubjScoreCA_3 = int(input('third assesment type score: '))
forthsubjexam = input('fourth assesment type: ')
forthsubjScoreExam = int(input('fourth assesment type score: '))




avg = 'avg'


firstSubj = firstSubj
quiz1 = int(firstsubjScoreCA_1)
homework1 = firstsubjScoreCA_2
attendance1 = firstsubjScoreCA_3
exam1 = firstsubjScoreExam
def avgperSub1score(quiz1, homework1, attendance1, exam1):
    quiz1 = (quiz1 / 190) * 30
    homework1 = (homework1 / 190) * 15
    attendance1 = (attendance1 / 96) * 12
    exam1 = (exam1 / 100) * 43
    avgSub1score = quiz1 + homework1 + attendance1 + exam1
    return avgSub1score
avgSub1score  = avgperSub1score(quiz1, homework1, attendance1, exam1)



secondSubj = secondSubj
quiz2 = secondsubjScoreCA_1
homework2 = secondsubjScoreCA_2
attendance2 = secondsubjScoreCA_3
exam2 = secondsubjScoreExam
def avgperSub2score(quiz2, homework2, attendance2, exam2):    
    quiz2 = (quiz2 / 190) * 30
    homework2 = (homework2 / 190) * 15
    attendance2 = (attendance2 / 96) * 12
    exam2 = (exam2 / 100) * 43
    avgSub2score = quiz2 + homework2 + attendance2 + exam2
    return avgSub2score
avgSub2score = avgperSub2score(quiz2, homework2, attendance2, exam2)


thirdSubj = thirdSubj
quiz3 = thirdsubjScoreCA_1
homework3 = thirdsubjScoreCA_2
attendance3 = thirdsubjScoreCA_3
exam3 = thirdsubjScoreExam
def avgperSub3score(quiz3, homework3, attendance3, exam3):
    quiz3 = (quiz3 / 190) * 30
    homework3 = (homework3 / 190) * 15
    attendance3 = (attendance3 / 96) * 12
    exam3 = (exam3 / 100) * 43
    avgSub3score = quiz3 + homework3 + attendance3 + exam3
    return avgSub3score
avgSub3score = avgperSub3score(quiz3, homework3, attendance3, exam3)


forthSubj = forthSubj
quiz4 = forthsubjScoreCA_1
homework4 = forthsubjScoreCA_2
attendance4 = forthsubjScoreCA_3
exam4 = forthsubjScoreExam
def avgperSub4score(quiz4, homework4, attendance4, exam4):
    quiz4 = (quiz4 / 190) * 30
    homework4 = (homework4 / 190) * 15
    attendance4 = (attendance4 / 96) * 12
    exam4 = (exam4 / 100) * 43
    avgSub4score = quiz4 + homework4 + attendance4 + exam4
    return avgSub4score
avgSub4score = avgperSub4score(quiz4, homework4, attendance4, exam4)


avgscore = 'avgscore'
def avgscorerecCre(avgSub1score, avgSub2score, avgSub3score, avgSub4score):
    avgscorerec = (avgSub1score + avgSub2score + avgSub3score + avgSub4score) / 4
    return avgscorerec 
avgscorerec = avgscorerecCre(avgSub1score, avgSub2score, avgSub3score, avgSub4score)


gpa = 'gpa'
def gparecCre(avgscorerec):
    gparec = (avgscorerec/100) * 5
    return gparec
gparec = gparecCre(avgscorerec)


grade = 'grade'
def graderecCre(avgscorerec):
    if avgscorerec >= 90:
        graderec = 'A'
    elif avgscorerec >= 75:
        graderec = 'B'
    elif avgscorerec >= 65:
        graderec = 'C'
    elif avgscorerec >= 55:
        graderec = 'D'
    elif avgscorerec >= 50:
        graderec = 'E'
    else:
        graderec = 'F'
    return graderec
graderec = graderecCre(avgscorerec)


status = 'status'
def statusrecCre(graderec):
    if graderec == 'A':
        statusrec = 'PASS'
    elif graderec == 'B':
        statusrec = 'PASS'
    elif graderec == 'C':
        statusrec = 'PASS'
    elif graderec == 'D':
        statusrec = 'PASS'
    elif graderec == 'E':
        statusrec = 'RETAKE'
    else:
        statusrec = 'FAIL'
    return statusrec
statusrec = statusrecCre(graderec)






studRecCreator(name, ID, firstSubj, firstsubjCA_1, firstsubjScoreCA_1, firstsubjCA_2, firstsubjScoreCA_2, firstsubjCA_3, firstsubjScoreCA_3, firstsubjexam, firstsubjScoreExam, secondSubj, secondsubjCA_1, secondsubjScoreCA_1, secondsubjCA_2, secondsubjScoreCA_2, secondsubjCA_3, secondsubjScoreCA_3, secondsubjexam, secondsubjScoreExam, thirdSubj, thirdsubjCA_1, thirdsubjScoreCA_1, thirdsubjCA_2, thirdsubjScoreCA_2, thirdsubjCA_3, thirdsubjScoreCA_3, thirdsubjexam, thirdsubjScoreExam, forthSubj, forthsubjCA_1, forthsubjScoreCA_1, forthsubjCA_2, forthsubjScoreCA_2, forthsubjCA_3, forthsubjScoreCA_3, forthsubjexam, forthsubjScoreExam, avg, avgSub1score, avgSub2score, avgSub3score, avgSub4score, avgscore, avgscorerec, gpa, gparec, grade, graderec, status, statusrec)
print(studRecords)
# Out:
# name: Bett James
# ID: GR-0483
# first subject: Chem
# first assesment type: Quiz
# first assesment type score: 127
# second assesment type: Homework
# second assesment type score: 135
# third assesment type:Attendance
# third assesment type score: 17
# fourth assesment type: Exam
# fourth assesment type score: 46
# second subject: Bio
# first assesment type: Quiz
# first assesment type score: 184
# second assesment type: Homework
# second assesment type score: 186
# third assesment type:Attendance
# third assesment type score: 58
# fourth assesment type: Exam
# fourth assesment type score: 97
# third subject: Phy
# first assesment type: Quiz
# first assesment type score: 52
# second assesment type: Homework
# second assesment type score: 142
# third assesment type:Attendance
# third assesment type score: 29
# fourth assesment type: Exam
# fourth assesment type score: 73
# forth subject: Math
# first assesment type: Quiz
# first assesment type score: 133
# ...

# %%
#3. Holds each student’s performance records in a container

studRecords['Bett James_GR-0483'][4]
# Out:
# [{'avg': [{'Chem': 52.615526315789474},
#    {'Bio': 92.69684210526316},
#    {'Phy': 54.436052631578946},
#    {'Math': 52.25789473684211}]},
#  {'avgscore': 63.00157894736842},
#  {'gpa': 3.1500789473684208, 'grade': 'D'},
#  {},
#  {'status': 'PASS'}]

# %%
#4. Holds each subject performance records in a container for all students

for name in studRecords.keys():
    res1 = studRecords.keys()
    print(res1)
    res = list(studRecords[name])[:3]
    print(res)
# Out:
# dict_keys(['Bett James_GR-0483', 'Namukolo Abrams_GR-0484'])
# [{'Chem': [{'Quiz': 127}, {'Homework': 135}, {'Attendance': 17}, {'Exam': 46}]}, {'Bio': [{'Quiz': 184}, {'Homework': 186}, {'Attendance': 58}, {'Exam': 97}]}, {'Phy': [{'Quiz': 52}, {'Homework': 142}, {'Attendance': 29}, {'Exam': 73}]}]
# dict_keys(['Bett James_GR-0483', 'Namukolo Abrams_GR-0484'])
# [{'Chem': [{'Quiz': 141}, {'Homework': 82}, {'Attendance': 95}, {'Exam': 52}]}, {'Bio': [{'Quiz': 177}, {'Homework': 170}, {'Attendance': 57}, {'Exam': 41}]}, {'Phy': [{'Quiz': 21}, {'Homework': 12}, {'Attendance': 43}, {'Exam': 31}]}]

# %%
#5 Holds ALL student performance records for ALL subjects in a container. Note: this container should hold all student scores for subjects quiz, homework and exam scores, Average Score, GPA, Grade and Status. All in a Container of containers

studRecords
# Out:
# {'Bett James_GR-0483': [{'Chem': [{'Quiz': 127},
#     {'Homework': 135},
#     {'Attendance': 17},
#     {'Exam': 46}]},
#   {'Bio': [{'Quiz': 184},
#     {'Homework': 186},
#     {'Attendance': 58},
#     {'Exam': 97}]},
#   {'Phy': [{'Quiz': 52}, {'Homework': 142}, {'Attendance': 29}, {'Exam': 73}]},
#   {'Math': [{'Quiz': 133},
#     {'Homework': 97},
#     {'Attendance': 34},
#     {'Exam': 45}]},
#   [{'avg': [{'Chem': 52.615526315789474},
#      {'Bio': 92.69684210526316},
#      {'Phy': 54.436052631578946},
#      {'Math': 52.25789473684211}]},
#    {'avgscore': 63.00157894736842},
#    {'gpa': 3.1500789473684208, 'grade': 'D'},
#    {},
#    {'status': 'PASS'}]],
#  'Namukolo Abrams_GR-0484': [{'Chem': [{'Quiz': 141},
#     {'Homework': 82},
#     {'Attendance': 95},
#     {'Exam': 52}]},
#   {'Bio': [{'Quiz': 177},
#     {'Homework': 170},
#     {'Attendance': 57},
#     {'Exam': 41}]},
#   {'Phy': [{'Quiz': 21}, {'Homework': 12}, {'Attendance': 43}, {'Exam': 31}]},
# ...

# %%
#1 The full performance records of any student by simply providing the student’s name or ID

name = input('name: ') 
ID = input('ID')


val = list(studRecords.keys())
for key in val:
    if name in key or ID in key:
        valID = key
    status = studRecords[valID]
print(status)
# Out:
# name: Namukolo Abrams
# IDIDGR-0484
# [{'Chem': [{'Quiz': 141}, {'Homework': 82}, {'Attendance': 95}, {'Exam': 52}]}, {'Bio': [{'Quiz': 177}, {'Homework': 170}, {'Attendance': 57}, {'Exam': 41}]}, {'Phy': [{'Quiz': 21}, {'Homework': 12}, {'Attendance': 43}, {'Exam': 31}]}, {'Math': [{'Quiz': 136}, {'Homework': 180}, {'Attendance': 48}, {'Exam': 31}]}, [{'avg': [{'Chem': 62.97184210526316}, {'Bio': 66.12342105263157}, {'Phy': 22.96815789473684}, {'Math': 55.014210526315786}]}, {'avgscore': 51.76940789473684}, {'gpa': 2.588470394736842, 'grade': 'E'}, {}, {'status': 'RETAKE'}]]

# %%
# 5 Obtain a response from the script for any student to determine if they passed, failed, or need to retake the subject 

name = input('name: ')
ID = input('ID')

val = list(studRecords.keys())
for key in val:
    if name in key or ID in key:
        valID = key
    status = studRecords[valID][4][4]
print(status)
# Out:
# name: Namukolo Abrams
# IDIDIDGR-0484
# {'status': 'RETAKE'}

# %%
#2 Any student’s performance for any given subject by simply providing student name/ID and subject name

name = input('name: ')
ID = input('ID: ')

val = list(studRecords.keys())
for key in val:
    if name in key or ID in key:
        valID = key
        




    
def chemfunc(subject):
    res = studRecords[valID][0]
    return res

def biofunc(subject):
    res = studRecords[valID][1]
    return res

def phyfunc(subject):
    res = studRecords[valID][2]
    return res

def mathfunc(subject):
    res = studRecords[valID][3]
    return res



subject = input('subject: ')

if subject == 'Chem':
    res = chemfunc(subject)
    print(res)
elif subject == 'Bio':
    res = biofunc(subject)
    print(res)
elif subject == 'Phy':
    res = phyfunc(subject)
    print(res)
elif subject == 'Math':
    res = mathfunc(subject)
    print(res)
# Out:
# name: Bett James
# ID: GR-0483
# subject: Phy
# {'Phy': [{'Quiz': 52}, {'Homework': 142}, {'Attendance': 29}, {'Exam': 73}]}

# %%
#3. Fetch the list of students in any of the grade categories (A, B, C, D, E, F)



for name in studRecords.keys():
    res1 = studRecords.keys()
    print(res1)
    res = list(studRecords[name])[4][2]
    print(res)
# Out:
# dict_keys(['Bett James_GR-0483', 'Namukolo Abrams_GR-0484'])
# {'gpa': 3.1500789473684208, 'grade': 'D'}
# dict_keys(['Bett James_GR-0483', 'Namukolo Abrams_GR-0484'])
# {'gpa': 2.588470394736842, 'grade': 'E'}

# %%
#4. Fetch the list of students Statuses (Pass, Fail, Retake) 


for name in studRecords.keys():
    res1 = studRecords.keys()
    print(res1)
    res = list(studRecords[name])[4][4]
    print(res)
# Out:
# dict_keys(['Bett James_GR-0483', 'Namukolo Abrams_GR-0484'])
# {'status': 'PASS'}
# dict_keys(['Bett James_GR-0483', 'Namukolo Abrams_GR-0484'])
# {'status': 'RETAKE'}
